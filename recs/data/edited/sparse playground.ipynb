# %%
from scipy import sparse
from matplotlib import pyplot as plt

A = sparse.random(10000,15000, density=0.00001)

# %%
plt.xlabel("Книги")
plt.ylabel("Користувачі")
plt.spy(A, markersize=1)

# %%
з
